# %% [markdown]
# #### import the proxy here

# %%
#pip install fastf1

# %%
import pandas as pd
import requests
import fastf1
import json

# %%
API_KEY = ‘YOUR_API_KEY’

def get_scraperapi_url(url):
    """
        Converts url into API request for ScraperAPI.
    """
    payload = {'api_key': API_KEY, 'url': url}
    proxy_url = 'http://api.scraperapi.com/?' + urlencode(payload)
    return proxy_url

# %%
import requests
import os

base_urls = [
    "http://ergast.com/api/f1/circuits.json",
    "https://ergast.com/api/f1/constructorStandings.json",
    "http://ergast.com/api/f1/constructors.json",
    "http://ergast.com/api/f1/driverstandings.json",
    "http://ergast.com/api/f1/drivers.json",
    "http://ergast.com/api/f1/qualifying.json",
    "http://ergast.com/api/f1/races.json",
    "https://ergast.com/api/f1/results.json",
    "http://ergast.com/api/f1/seasons.json",
    "https://ergast.com/api/f1/sprint.json",
    "http://ergast.com/api/f1/status.json",
    "https://ergast.com/docs/f1db_user_guide.txt"
]
for url in base_urls:
    payload = {'api_key': 'APIKEY', 'url': 'https://httpbin.org/ip'}
    driver.get(get_scraperapi_url(url))
    response = requests.get('http://api.scraperapi.com', params=payload)
    file_name = os.path.basename(url)
    with open(file_name, 'wb') as file:
        file.write(response.content)

# %%
import pandas as pd
import json

def get_and_save_data(url, filename):
    response = requests.get(url)
    data = response.json()

    if 'RaceTable' in data['MRData']:
        df = pd.json_normalize(data['MRData']['RaceTable']['Races'])
    elif 'StandingsTable' in data['MRData']:
        df = pd.json_normalize(data['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings'])
    else:
        df = pd.json_normalize(data['MRData'])

    df.to_csv(csv_filename, index=False)

filenames = [
    "circuits.json",
    "constructorStandings.json",
    "constructors.json",
    "driverstandings.json",
    "drivers.json",
    "qualifying.json",
    "races.json",
    "results.json",
    "seasons.json",
    "status.json",
]

# %%
# Extract nested 'Circuits' data
circuits = pd.read_json('circuits.json')
data_circuits = pd.json_normalize(circuits['MRData']['CircuitTable']['Circuits'])

# %%
constructor_standings = pd.read_json('constructorStandings.json')
data_constructor_standings = pd.json_normalize(constructor_standings['MRData']['StandingsTable']['StandingsLists'][0]['ConstructorStandings'])
data_constructor_standings
# Out:
#   position positionText points wins Constructor.constructorId  \
# 0        1            1     48    6                   vanwall
# 1        2            2     40    2                   ferrari
# 2        3            3     31    2                    cooper
# 3        4            4     18    0                       brm
# 4        5            5      6    0                  maserati
# 5        6            6      3    0                team_lotus
# 6        7            7      0    0                   porsche
# 7        8            8      0    0                 connaught
# 8        9            9      0    0                      osca
#
#                                      Constructor.url Constructor.name  \
# 0               http://en.wikipedia.org/wiki/Vanwall          Vanwall
# 1      http://en.wikipedia.org/wiki/Scuderia_Ferrari          Ferrari
# 2    http://en.wikipedia.org/wiki/Cooper_Car_Company           Cooper
# ...

# %%
constructors = pd.read_json('constructors.json')
data_constructors = pd.json_normalize(constructors['MRData']['ConstructorTable']['Constructors'])
data_constructors
# Out:
#          constructorId                                                url  \
# 0                adams   http://en.wikipedia.org/wiki/Adams_(constructor)
# 1                  afm  http://en.wikipedia.org/wiki/Alex_von_Falkenha...
# 2                  ags  http://en.wikipedia.org/wiki/Automobiles_Gonfa...
# 3                 alfa  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...
# 4           alphatauri   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 5               alpine        http://en.wikipedia.org/wiki/Alpine_F1_Team
# 6                 alta  http://en.wikipedia.org/wiki/Alta_auto_racing_...
# 7                 amon  http://en.wikipedia.org/wiki/Amon_(Formula_One...
# 8                 moda   http://en.wikipedia.org/wiki/Andrea_Moda_Formula
# 9              apollon  http://en.wikipedia.org/wiki/Apollon_(Formula_...
# 10              arrows  http://en.wikipedia.org/wiki/Arrows_Grand_Prix...
# 11      arzani-volpini        http://en.wikipedia.org/wiki/Arzani-Volpini
# ...

# %%
drivers = pd.read_json('drivers.json')
data_drivers = pd.json_normalize(drivers['MRData']['DriverTable']['Drivers'])
data_drivers
# Out:
#           driverId                                                url  \
# 0            abate     http://en.wikipedia.org/wiki/Carlo_Mario_Abate
# 1        abecassis      http://en.wikipedia.org/wiki/George_Abecassis
# 2          acheson         http://en.wikipedia.org/wiki/Kenny_Acheson
# 3            adams        http://en.wikipedia.org/wiki/Philippe_Adams
# 4             ader             http://en.wikipedia.org/wiki/Walt_Ader
# 5           adolff           http://en.wikipedia.org/wiki/Kurt_Adolff
# 6       agabashian       http://en.wikipedia.org/wiki/Fred_Agabashian
# 7           ahrens      http://en.wikipedia.org/wiki/Kurt_Ahrens,_Jr.
# 8           aitken           http://en.wikipedia.org/wiki/Jack_Aitken
# 9           albers     http://en.wikipedia.org/wiki/Christijan_Albers
# 10           albon       http://en.wikipedia.org/wiki/Alexander_Albon
# 11        alboreto      http://en.wikipedia.org/wiki/Michele_Alboreto
# ...

# %%
driver_standings = pd.read_json('driverstandings.json')
data_driver_standings = pd.json_normalize(driver_standings['MRData']['StandingsTable']['StandingsLists'][0]['DriverStandings'])
data_driver_standings
# Out:
#    position positionText points wins  \
# 0         1            1     30    3
# 1         2            2     27    3
# 2         3            3     24    0
# 3         4            4     13    0
# 4         5            5     11    0
# 5         6            6      9    1
# 6         7            7      6    0
# 7         8            8      5    0
# 8         9            9      4    0
# 9        10           10      4    0
# 10       11           11      4    0
# 11       12           12      4    0
# 12       13           13      3    0
# 13       14           14      3    0
# 14       15           15      3    0
# 15       16           16      3    0
# 16       17           17      3    0
# 17       18           18      3    0
# 18       19           19      2    0
# 19       20           20      1    0
# 20       21           21      1    0
# 21       22           22      1    0
# 22       23           23      0    0
# 23       24           24      0    0
# ...

# %%
qualifying = pd.read_json('qualifying.json')
qualifying_results_flattened = pd.json_normalize(races_flattened.loc[0, 'QualifyingResults'])
qualifying_flattened
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/Final_task_ds/lib/python3.9/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/Final_task_ds/lib/python3.9/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/Final_task_ds/lib/python3.9/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'QualifyingResults'
#
# ...

# %%
races = pd.read_json('races.json')
races_flattened = pd.json_normalize(races['MRData']['RaceTable']['Races'])
races_flattened
# Out:
#    season round                                                url  \
# 0    1950     1  http://en.wikipedia.org/wiki/1950_British_Gran...
# 1    1950     2  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
# 2    1950     3  http://en.wikipedia.org/wiki/1950_Indianapolis...
# 3    1950     4  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...
# 4    1950     5  http://en.wikipedia.org/wiki/1950_Belgian_Gran...
# 5    1950     6  http://en.wikipedia.org/wiki/1950_French_Grand...
# 6    1950     7  http://en.wikipedia.org/wiki/1950_Italian_Gran...
# 7    1951     1  http://en.wikipedia.org/wiki/1951_Swiss_Grand_...
# 8    1951     2  http://en.wikipedia.org/wiki/1951_Indianapolis...
# 9    1951     3  http://en.wikipedia.org/wiki/1951_Belgian_Gran...
# 10   1951     4  http://en.wikipedia.org/wiki/1951_French_Grand...
# 11   1951     5  http://en.wikipedia.org/wiki/1951_British_Gran...
# 12   1951     6  http://en.wikipedia.org/wiki/1951_German_Grand...
# ...

# %%
results = pd.read_json('results.json')
results_data = pd.json_normalize(results['MRData']['RaceTable']['Races'])
results_data.head()
# Out:
#   season round                                                url  \
# 0   1950     1  http://en.wikipedia.org/wiki/1950_British_Gran...
# 1   1950     2  http://en.wikipedia.org/wiki/1950_Monaco_Grand...
#
#              raceName        date  \
# 0  British Grand Prix  1950-05-13
# 1   Monaco Grand Prix  1950-05-21
#
#                                              Results Circuit.circuitId  \
# 0  [{'number': '2', 'position': '1', 'positionTex...       silverstone
# 1  [{'number': '34', 'position': '1', 'positionTe...            monaco
#
#                                         Circuit.url  Circuit.circuitName  \
# 0  http://en.wikipedia.org/wiki/Silverstone_Circuit  Silverstone Circuit
# 1    http://en.wikipedia.org/wiki/Circuit_de_Monaco    Circuit de Monaco
#
#   Circuit.Location.lat Circuit.Location.long Circuit.Location.locality  \
# 0              52.0786              -1.01694               Silverstone
# 1              43.7347               7.42056               Monte-Carlo
#
# ...

# %%
seasons = pd.read_json('seasons.json')
seasons_data = pd.json_normalize(seasons['MRData']['SeasonTable']['Seasons'])
seasons_data
# Out:
#    season                                                url
# 0    1950  http://en.wikipedia.org/wiki/1950_Formula_One_...
# 1    1951  http://en.wikipedia.org/wiki/1951_Formula_One_...
# 2    1952  http://en.wikipedia.org/wiki/1952_Formula_One_...
# 3    1953  http://en.wikipedia.org/wiki/1953_Formula_One_...
# 4    1954  http://en.wikipedia.org/wiki/1954_Formula_One_...
# 5    1955  http://en.wikipedia.org/wiki/1955_Formula_One_...
# 6    1956  http://en.wikipedia.org/wiki/1956_Formula_One_...
# 7    1957  http://en.wikipedia.org/wiki/1957_Formula_One_...
# 8    1958  http://en.wikipedia.org/wiki/1958_Formula_One_...
# 9    1959  http://en.wikipedia.org/wiki/1959_Formula_One_...
# 10   1960  http://en.wikipedia.org/wiki/1960_Formula_One_...
# 11   1961  http://en.wikipedia.org/wiki/1961_Formula_One_...
# 12   1962  http://en.wikipedia.org/wiki/1962_Formula_One_...
# 13   1963  http://en.wikipedia.org/wiki/1963_Formula_One_...
# ...

# %%
sprint = pd.read_json('sprint.json')
sprint_data = pd.json_normalize(sprint['MRData']['RaceTable']['Races'])
sprint_data
# Out:
#   season round                                                url  \
# 0   2021    10  http://en.wikipedia.org/wiki/2021_British_Gran...
# 1   2021    14  http://en.wikipedia.org/wiki/2021_Italian_Gran...
#
#              raceName        date       time  \
# 0  British Grand Prix  2021-07-18  14:00:00Z
# 1  Italian Grand Prix  2021-09-12  13:00:00Z
#
#                                        SprintResults Circuit.circuitId  \
# 0  [{'number': '33', 'position': '1', 'positionTe...       silverstone
# 1  [{'number': '77', 'position': '1', 'positionTe...             monza
#
#                                          Circuit.url  \
# 0   http://en.wikipedia.org/wiki/Silverstone_Circuit
# 1  http://en.wikipedia.org/wiki/Autodromo_Naziona...
#
#             Circuit.circuitName Circuit.Location.lat Circuit.Location.long  \
# 0           Silverstone Circuit              52.0786              -1.01694
# 1  Autodromo Nazionale di Monza              45.6156               9.28111
#
# ...

# %%
status = pd.read_json('status.json')
status_data = pd.json_normalize(status['MRData']['StatusTable']['Status'])
status_data
# Out:
#    statusId count        status
# 0         1  7228      Finished
# 1         2   143  Disqualified
# 2         3  1048      Accident
# 3         4   838     Collision
# 4         5  2016        Engine
# 5         6   805       Gearbox
# 6         7   321  Transmission
# 7         8   214        Clutch
# 8         9   138    Hydraulics
# 9        10   316    Electrical
# 10       11  3894        +1 Lap
# 11       12  1598       +2 Laps
# 12       13   731       +3 Laps
# 13       14   405       +4 Laps
# 14       15   221       +5 Laps
# 15       16   153       +6 Laps
# 16       17    99       +7 Laps
# 17       18    52       +8 Laps
# 18       19    38       +9 Laps
# 19       20   792      Spun off
# 20       21    42      Radiator
# 21       22   431    Suspension
# 22       23   252        Brakes
# 23       24    61  Differential
# 24       25   131   Overheating
# 25       26    29    Mechanical
# 26       27    55          Tyre
# 27       28     1   Driver Seat
# ...

# %%
laps_urls = []

for season in range(1996, 2024):
    for race_round in range(1, 25):
        for lap_num in range(1, 78):
            url = f"https://ergast.com/api/f1/{season}/{race_round}/laps/{lap_num}"
            laps_urls.append(url)

pit_speed_urls = []
for season in range(2012, 2024):
    for race_round in range(1, 25):
            url = f"https://ergast.com/api/f1/{season}/{race_round}/pitstops.json"
            pit_speed_urls.append(url)
pit_speed_urls
# Out:
# ['https://ergast.com/api/f1/2012/1/pitstops.json',
#  'https://ergast.com/api/f1/2012/2/pitstops.json',
#  'https://ergast.com/api/f1/2012/3/pitstops.json',
#  'https://ergast.com/api/f1/2012/4/pitstops.json',
#  'https://ergast.com/api/f1/2012/5/pitstops.json',
#  'https://ergast.com/api/f1/2012/6/pitstops.json',
#  'https://ergast.com/api/f1/2012/7/pitstops.json',
#  'https://ergast.com/api/f1/2012/8/pitstops.json',
#  'https://ergast.com/api/f1/2012/9/pitstops.json',
#  'https://ergast.com/api/f1/2012/10/pitstops.json',
#  'https://ergast.com/api/f1/2012/11/pitstops.json',
#  'https://ergast.com/api/f1/2012/12/pitstops.json',
#  'https://ergast.com/api/f1/2012/13/pitstops.json',
#  'https://ergast.com/api/f1/2012/14/pitstops.json',
#  'https://ergast.com/api/f1/2012/15/pitstops.json',
#  'https://ergast.com/api/f1/2012/16/pitstops.json',
#  'https://ergast.com/api/f1/2012/17/pitstops.json',
#  'https://ergast.com/api/f1/2012/18/pitstops.json',
# ...

# %%
for url in laps_urls:
    response = requests.get(url)
    file_name = os.path.basename(url)
    with open(file_name, 'wb') as file:
        file.write(response.content)

# %%
for url in laps_urls:
    response = requests.get(url)
    file_name = os.path.basename(url)
    with open(file_name, 'wb') as file:
        file.write(response.content)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/Final_task_ds/lib/python3.9/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# ...
