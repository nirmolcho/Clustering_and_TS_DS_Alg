# %%
import pandas_datareader as pdd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
tech_list = ['AAPL','MSFT','HALO','AMZN','GOOG']
end = datetime.now()
start = datetime(end.year-1,end.month,end.day)

# %%
for stock in tech_list:
    globals()[stock] = pdd.data.DataReader(stock,'yahoo',start,end)

# %%
AAPL
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-12-13  172.100006  169.130005  172.000000  169.567505  62170000.0
# 2021-12-14  169.498993  166.440002  167.550003  169.091507  55976000.0
# 2021-12-15  173.600006  165.195007  168.598007  173.315002  75794000.0
# 2021-12-16  174.166000  168.160507  173.368500  168.871002  60876000.0
# 2021-12-17  170.898499  165.613495  167.710495  170.017502  85542000.0
# ...                ...         ...         ...         ...         ...
# 2022-12-06   91.040001   87.900002   90.500000   88.250000  75503600.0
# 2022-12-07   89.889999   87.480003   88.339996   88.459999  68086900.0
# 2022-12-08   90.860001   87.879997   89.239998   90.349998  73305900.0
# 2022-12-09   90.300003   88.629997   88.900002   89.089996  67316900.0
# 2022-12-12   90.580002   87.870003   89.209999   90.550003  61852400.0
#
#              Adj Close
# Date
# 2021-12-13  169.567505
# 2021-12-14  169.091507
# 2021-12-15  173.315002
# 2021-12-16  168.871002
# 2021-12-17  170.017502
# ...                ...
# 2022-12-06   88.250000
# 2022-12-07   88.459999
# 2022-12-08   90.349998
# 2022-12-09   89.089996
# 2022-12-12   90.550003
#
# [252 rows x 6 columns]

# %%
AAPL.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  252.000000  252.000000  252.000000  252.000000  2.520000e+02
# mean   159.148095  154.921786  157.000754  157.088452  8.891628e+07
# std     12.775973   12.987144   12.980935   12.870579  2.524959e+07
# min    132.389999  129.039993  130.070007  130.059998  3.519590e+07
# 25%    148.075005  144.239994  145.817505  146.474998  7.152005e+07
# 50%    158.580002  153.934998  156.555000  156.779999  8.447425e+07
# 75%    170.549995  166.642498  168.764996  168.527504  9.821470e+07
# max    182.940002  179.119995  182.630005  182.009995  1.954327e+08
#
#         Adj Close
# count  252.000000
# mean   156.580730
# std     12.654395
# min    129.664490
# 25%    146.131775
# 50%    156.078911
# 75%    167.925320
# max    180.959732

# %%
AAPL['Close'].plot(figsize=(12,3))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
AAPL['Volume'].plot(figsize=(12,3))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ma_day=[10,20,50]
for ma in ma_day:
    column_name = "MA for %s days" % str(ma)
    AAPL[column_name] = AAPL['Close'].rolling(window=ma).mean()

# %%
AAPL.head(20)
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 

# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sns.set(rc={'figure.figsize':(15.7,4.27)})
sns.distplot(AAPL['Daily Return'],bins=100,color='purple')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Daily Return', ylabel='Density'>

# %%
closing_df = pdd.data.DataReader(tech_list,'yahoo',start,end)['Close']

# %%
closing_df
# Out:
# Symbols           AAPL        MSFT       HALO        AMZN        GOOG
# Date
# 2021-12-13  175.740005  339.399994  34.660000  169.567505  146.704498
# 2021-12-14  174.330002  328.339996  34.639999  169.091507  144.970505
# 2021-12-15  179.300003  334.649994  36.930000  173.315002  147.368500
# 2021-12-16  172.259995  324.899994  35.639999  168.871002  144.838501
# 2021-12-17  171.139999  323.799988  38.529999  170.017502  142.802994
# ...                ...         ...        ...         ...         ...
# 2022-12-06  142.910004  245.119995  56.380001   88.250000   97.309998
# 2022-12-07  140.940002  244.369995  57.740002   88.459999   95.150002
# 2022-12-08  142.649994  247.399994  57.849998   90.349998   93.949997
# 2022-12-09  142.160004  245.419998  56.930000   89.089996   93.070000
# 2022-12-12  144.490005  252.509995  58.049999   90.550003   93.559998
#
# [252 rows x 5 columns]

# %%
tech_rets = closing_df.pct_change()
tech_rets.head()
# Out:
# Symbols         AAPL      MSFT      HALO      AMZN      GOOG
# Date
# 2021-12-13       NaN       NaN       NaN       NaN       NaN
# 2021-12-14 -0.008023 -0.032587 -0.000577 -0.002807 -0.011820
# 2021-12-15  0.028509  0.019218  0.066109  0.024978  0.016541
# 2021-12-16 -0.039264 -0.029135 -0.034931 -0.025641 -0.017168
# 2021-12-17 -0.006502 -0.003386  0.081089  0.006789 -0.014054

# %%
sns.jointplot('AAPL','MSFT',tech_rets,color='seagreen')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot('GOOG','MSFT',tech_rets,color='seagreen')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(tech_rets)

# %%
returns_fig = sns.PairGrid(tech_rets)
returns_fig.map_upper(plt.scatter,color='green')
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')
returns_fig.map_diag(plt.hist,bins=20)

# %%
returns_fig = sns.PairGrid(closing_df)
returns_fig.map_upper(plt.scatter,color='green')
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')
returns_fig.map_diag(plt.hist,bins=20)

# %%
rets = tech_rets.dropna()

# %%
len(rets)
# Out:
# 251

# %%
plt.scatter(rets.mean(),rets.std())

# %%
plt.scatter(rets.mean(),rets.std())
for label,x,y in zip(rets.columns,rets.mean(),rets.std()):
    plt.xlim([-0.0022,0.0025])
    plt.ylim([0.02,0.035])
    plt.annotate(
        label,
        xy=(x,y),
        xytext=(50,50),
        textcoords='offset points',ha='right',va='bottom',
    arrowprops=dict(arrowstyle='-',edgecolor='blue',connectionstyle='arc3,rad=-0.3'))
